# %% [markdown]
# # Read Danmarks Statstik API

# %% [markdown]
# ## Summary
# #### Base URL
# - __https://api.statbank.dk/v1/__
# #### Target Data
# You can request the following groups of resources (here called 'target'):
# - '__subjects__'
# - '__tables__'
# - '__tableinfo__' (metadata of tables)
# - '__data__' (table content)
# First choose the group and then choose one, more, or all data sources from that target group. Each must be identified by ID or name. For 'all' write ['*'].
# #### REST Function
# It is possible to request data with either __get()__ or __post()__ request. Here you will find examples with both.
# <br>
# See more parameters [here](https://www.dst.dk/da/Statistik/hjaelp-til-statistikbanken/api) and
# [here](https://api.statbank.dk/console).<br>

# %% [markdown]
# ## Import Libraries

# %%
# Start by importing necessary packages
import requests
import pandas as pd
import json
import csv
from io import StringIO
from IPython.display import display

# %%
# always
baseurl = 'https://api.statbank.dk/v1/'

# %% [markdown]
# ## Create Our Functions
# Here I create two Python functions - one that uses get() request to the API and one - post(). One advantage of creating functions is their reusability. The functions have formal arguments, which I will replace with the actual ones at the time of their invocation.

# %%
# get() function, which I will use for getting 'subjects', 'tableinfo' or 'tables' 
def getDanStat(baseurl, target, targetid, outformat, language):  
    fullurl = baseurl + target
    params = {'id':targetid, 'format':outformat, 'lang':language}
    response = requests.get(fullurl, params=params)
    return response

# %%
# post() function I will use for getting 'data'
def postDanStat(baseurl, target, targetid, variables, outformat, language):  
    fullurl = baseurl + target
    params = { "table": targetid,
               "format": outformat,
               "variables": variables
             }
    response = requests.post(fullurl, json=params)
    return response

# %% [markdown]
# ## Test Functions Invocation
# Try yourself with requests to different targets.

# %% [markdown]
# ### Test getDanStat()

# %%
# target (see targets above)
target = 'tables'

# %%
# get the id from the website
targetid = 'metrox1'

# %%
# json, csv, html, ...
outformat = 'csv'

# %%
# 'da' or 'en', Danish default
language = 'da'

# %%
# function call
response = getDanStat(baseurl, target, targetid, outformat, language).json()

# %%
response
# Out:
# [{'id': 'FOLK1A',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'civilstand', 'tid']},
#  {'id': 'FOLK1AM',
#   'text': 'Befolkningen den 1. i måneden',
#   'unit': 'Antal',
#   'updated': '2026-01-12T08:00:00',
#   'firstPeriod': '2021M10',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'tid']},
#  {'id': 'BEFOLK1',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1971',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'civilstand', 'tid']},
#  {'id': 'BEFOLK2',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'tid']},
#  {'id': 'FOLK3',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['fødselsdag', 'fødselsmåned', 'fødselsår', 'tid']},
#  {'id': 'FOLK3FOD',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['fødselsdag', 'fødselsmåned', 'fødeland', 'tid']},
#  {'id': 'BEF5',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1990',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'fødeland', 'tid']},
#  {'id': 'FT',
#   'text': 'Befolkningen (summariske tal fra folketællinger)',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1769',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['hovedlandsdele', 'tid']},
#  {'id': 'HISB3',
#   'text': 'Nøgletal om befolkningen',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['bevægelsesart', 'tid']},
#  {'id': 'BY1',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-05-14T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['byområder og landdistrikter', 'alder', 'køn', 'tid']},
#  {'id': 'BY2',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-05-14T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['kommune', 'bystørrelse', 'alder', 'køn', 'tid']},
#  {'id': 'BY3',
#   'text': 'Befolkningen 1. januar',
#   'unit': '-',
#   'updated': '2025-06-10T08:00:00',
#   'firstPeriod': '2017',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['byområder og landdistrikter',
#    'folketal areal og befolkningstæthed',
#    'tid']},
#  {'id': 'BEF4',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-04-03T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['øer', 'tid']},
#  {'id': 'POSTNR1',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['postnumre', 'køn', 'alder', 'tid']},
#  {'id': 'POSTNR2',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['postnumre', 'køn', 'alder', 'tid']},
#  {'id': 'KM1',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2007K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['sogn', 'folkekirkemedlemsskab', 'tid']},
#  {'id': 'SOGN1',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['sogn', 'køn', 'alder', 'tid']},
#  {'id': 'LABY02',
#   'text': 'Befolkningen i procent af alle i samme kommunegruppe',
#   'unit': 'Pct.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['kommunegruppe', 'alder', 'tid']},
#  {'id': 'LABY03',
#   'text': 'Befolkningen i procent af alle i samme alder',
#   'unit': 'Pct.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['kommunegruppe', 'alder', 'tid']},
#  {'id': 'LABY05',
#   'text': 'Personer, der bor i samme kommunegruppe som for 20 år siden',
#   'unit': 'Pct.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['kommunegruppe', 'alder', 'tid']},
#  {'id': 'BEF5F',
#   'text': 'Personer født på Færøerne og bosat i Danmark 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'forældrenes fødested', 'tid']},
#  {'id': 'BEF5G',
#   'text': 'Personer født i Grønland og bosat i Danmark 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'forældrenes fødested', 'tid']},
#  {'id': 'BEV22',
#   'text': 'Befolkningens udvikling (foreløbig opgørelse)',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2007K2',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['område', 'bevægelsesart', 'køn', 'tid']},
#  {'id': 'LABY01',
#   'text': 'Befolkningstilvækst pr. 1.000 indbyggere',
#   'unit': 'Pr. 1.000 indb.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['kommunegruppe', 'bevægelsesart', 'tid']},
#  {'id': 'BEV107',
#   'text': 'Befolkningens udvikling',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'bevægelsesart', 'køn', 'tid']},
#  {'id': 'KMSTA003',
#   'text': 'Befolkningens udvikling',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['sogn', 'bevægelser', 'tid']},
#  {'id': 'GALDER',
#   'text': 'Gennemsnitsalder',
#   'unit': 'Gns.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2005',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['kommune', 'køn', 'tid']},
#  {'id': 'KMGALDER',
#   'text': 'Gennemsnitsalder',
#   'unit': 'Gns.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['sogn', 'køn', 'tid']},
#  {'id': 'FOLK1B',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'statsborgerskab', 'tid']},
#  {'id': 'FOLK1C',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'herkomst',
#    'oprindelsesland',
#    'tid']},
#  {'id': 'FOLK1D',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'statsborgerskab', 'tid']},
#  {'id': 'FOLK1E',
#   'text': 'Befolkningen den 1. i kvartalet',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K4',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'herkomst', 'tid']},
#  {'id': 'FOLK2',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['alder',
#    'køn',
#    'herkomst',
#    'statsborgerskab',
#    'oprindelsesland',
#    'tid']},
#  {'id': 'DKSTAT',
#   'text': 'Personer, der har fået dansk statsborgerskab',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1979',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'tidligere statsborgerskab', 'tid']},
#  {'id': 'IEPCT',
#   'text': 'Herkomstgruppernes andel af hele befolkningen 1. januar',
#   'unit': 'Pct.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['herkomst', 'tid']},
#  {'id': 'KMSTA001',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['sogn', 'herkomst', 'folkekirkemedlemsskab', 'tid']},
#  {'id': 'KRYDS1',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Hovedpersons herkomst',
#    'Hovedpersons fødeland',
#    'Hovedpersons statsborgerskab',
#    'Moders fødeland',
#    'moders statsborgerskab',
#    'Faders fødeland',
#    'faders statsborgerskab',
#    'tid']},
#  {'id': 'KRYDS2',
#   'text': 'Personer med dansk oprindelse 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Hovedpersons fødeland',
#    'forældres fødeland og statsborgerskab',
#    'hovedpersonens alder',
#    'tid']},
#  {'id': 'KRYDS3',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Hovedpersons herkomst',
#    'Hovedpersons fødeland',
#    'Moders fødeland',
#    'Faders fødeland',
#    'tid']},
#  {'id': 'KRYDS4',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Hovedpersons herkomst',
#    'forældres fødeland og statsborgerskab',
#    'hovedpersonens alder',
#    'tid']},
#  {'id': 'INDOPH1',
#   'text': 'Indvandrere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['første opholdsgrundlag', 'område', 'tid']},
#  {'id': 'INDOPH2',
#   'text': 'Indvandrere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['første opholdsgrundlag', 'oprindelseslandegruppe', 'tid']},
#  {'id': 'INDOPH3',
#   'text': 'Indvandrere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-04-04T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['nuværende opholdsgrundlag', 'område', 'tid']},
#  {'id': 'INDOPH4',
#   'text': 'Indvandrere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-04-04T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['nuværende opholdsgrundlag', 'oprindelseslandegruppe', 'tid']},
#  {'id': 'EB1',
#   'text': 'Børn af efterkommere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Oprindelig herkomst',
#    'køn',
#    'alder',
#    'oprindelsesland',
#    'tid']},
#  {'id': 'EB2',
#   'text': 'Børn af efterkommere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Oprindelig herkomst',
#    'køn',
#    'alder',
#    'oprindelsesland',
#    'tid']},
#  {'id': 'EB3',
#   'text': 'Børn af efterkommere 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['Oprindelig herkomst',
#    'køn',
#    'alder',
#    'oprindelsesland',
#    'område',
#    'tid']},
#  {'id': 'EB4',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['herkomst',
#    'køn',
#    'alder',
#    'oprindelsesland',
#    'område',
#    'tid']},
#  {'id': 'VAN5M',
#   'text': 'Asylansøgninger',
#   'unit': 'Antal',
#   'updated': '2026-01-20T08:00:00',
#   'firstPeriod': '2014M01',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['statsborgerskab', 'asyltype', 'tid']},
#  {'id': 'VAN5RKAM',
#   'text': 'Asylansøgninger (registreringstallet)',
#   'unit': 'Antal',
#   'updated': '2026-01-20T08:00:00',
#   'firstPeriod': '2014M01',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['statsborgerskab', 'køn', 'alder', 'tid']},
#  {'id': 'VAN66',
#   'text': 'Opholdstilladelser (år)',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '1997',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['statsborgerskab', 'opholdstilladelse', 'tid']},
#  {'id': 'VAN66KA',
#   'text': 'Opholdstilladelser (år)',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '2014',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['statsborgerskab',
#    'opholdstilladelse',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'VAN66P',
#   'text': 'Permanente opholdstilladelser (år)',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '2003',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['statsborgerskab', 'opholdstilladelse', 'tid']},
#  {'id': 'VAN77M',
#   'text': 'Opholdstilladelser (månedlig)',
#   'unit': 'Antal',
#   'updated': '2026-01-20T08:00:00',
#   'firstPeriod': '2014M01',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['statsborgerskab', 'opholdstilladelse', 'tid']},
#  {'id': 'VAN77KAM',
#   'text': 'Opholdstilladelser (månedlig)',
#   'unit': 'Antal',
#   'updated': '2026-01-20T08:00:00',
#   'firstPeriod': '2014M01',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['statsborgerskab',
#    'opholdstilladelse',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'VAN77PM',
#   'text': 'Permanente opholdstilladelser (månedlig)',
#   'unit': 'Antal',
#   'updated': '2026-01-20T08:00:00',
#   'firstPeriod': '2015M01',
#   'latestPeriod': '2025M12',
#   'active': True,
#   'variables': ['statsborgerskab', 'opholdstilladelse', 'tid']},
#  {'id': 'VAN8K',
#   'text': 'Indvandringer (foreløbig opgørelse) (kvartal)',
#   'unit': 'Antal',
#   'updated': '2025-11-17T08:00:00',
#   'firstPeriod': '2016K1',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['statsborgerskab', 'køn', 'opholdstilladelse', 'tid']},
#  {'id': 'VAN8A',
#   'text': 'Indvandringer (år)',
#   'unit': 'Antal',
#   'updated': '2025-03-25T08:00:00',
#   'firstPeriod': '1997',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['statsborgerskab', 'køn', 'opholdstilladelse', 'tid']},
#  {'id': 'FRDK125',
#   'text': 'Befolkningsfremskrivning 2025 for hele landet',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2070',
#   'active': True,
#   'variables': ['herkomst', 'køn', 'alder', 'tid']},
#  {'id': 'FRLD125',
#   'text': 'Befolkningsfremskrivning 2025',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2050',
#   'active': True,
#   'variables': ['region/landsdel', 'alder', 'køn', 'tid']},
#  {'id': 'FRKM125',
#   'text': 'Befolkningsfremskrivning 2025',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2050',
#   'active': True,
#   'variables': ['kommune', 'alder', 'køn', 'tid']},
#  {'id': 'FRDK225',
#   'text': 'Nøgletal 2025: Fremskrivning af befolkningens bevægelser',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2070',
#   'active': True,
#   'variables': ['herkomst', 'bevægelsesart', 'tid']},
#  {'id': 'FRLD225',
#   'text': 'Nøgletal 2025: Fremskrivning af befolkningens bevægelser',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2050',
#   'active': True,
#   'variables': ['landsdel', 'bevægelsesart', 'tid']},
#  {'id': 'FRKM225',
#   'text': 'Nøgletal 2025: Fremskrivning af befolkningens bevægelser',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2050',
#   'active': True,
#   'variables': ['kommune', 'bevægelsesart', 'tid']},
#  {'id': 'FRDK325',
#   'text': 'Forudsætninger vedrørende fertilitet til befolkningsfremskrivningen 2025',
#   'unit': 'Fertilitetskvotient',
#   'updated': '2025-06-27T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2069',
#   'active': True,
#   'variables': ['alder', 'herkomst', 'tid']},
#  {'id': 'FRDK425',
#   'text': 'Forudsætninger vedrørende dødelighed til befolkningsfremskrivningen 2025',
#   'unit': '-',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2069',
#   'active': True,
#   'variables': ['køn', 'alder', 'dødelighedstavle', 'tid']},
#  {'id': 'FRDK525',
#   'text': 'Forudsætninger vedrørende vandringer til befolkningsfremskrivningen 2025',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2069',
#   'active': True,
#   'variables': ['køn', 'alder', 'herkomst', 'bevægelse', 'tid']},
#  {'id': 'FRBEV25',
#   'text': 'Befolkningens udvikling',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '1992',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['bevægelsesart', 'køn', 'tid']},
#  {'id': 'FRGNSK25',
#   'text': 'Befolkningens udvikling',
#   'unit': 'Antal',
#   'updated': '2025-06-04T08:00:00',
#   'firstPeriod': '1992',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['bevægelsesart', 'alder', 'køn', 'tid']},
#  {'id': 'FOD',
#   'text': 'Levendefødte',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1973',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['moders alder', 'barnets køn', 'tid']},
#  {'id': 'FODIE',
#   'text': 'Levendefødte',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område',
#    'moders herkomst',
#    'moders oprindelsesland',
#    'moders statsborgerskab',
#    'moders alder',
#    'barnets køn',
#    'tid']},
#  {'id': 'FODDAG',
#   'text': 'Levendefødte',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['fødselsdag', 'fødselsmåned', 'tid']},
#  {'id': 'FODPM',
#   'text': 'Levendefødte',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['moders alder', 'levendefødtnummer', 'tid']},
#  {'id': 'FODPF',
#   'text': 'Levendefødte',
#   'unit': 'Antal',
#   'updated': '2025-08-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['faders alder', 'levendefødtnummer', 'tid']},
#  {'id': 'BEV3A',
#   'text': 'Levendefødte og døde',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '1901M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['bevægelse', 'tid']},
#  {'id': 'KM3',
#   'text': 'Levendefødte og døde',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2007K1',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['sogn', 'bevægelse', 'tid']},
#  {'id': 'FOD8',
#   'text': 'Enkelt- og flerfødsler',
#   'unit': 'Antal',
#   'updated': '2024-12-18T08:00:00',
#   'firstPeriod': '1850',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['fødselstype', 'tid']},
#  {'id': 'FOD9',
#   'text': 'Tvillingefødsler fordelt',
#   'unit': 'Antal',
#   'updated': '2024-12-18T08:00:00',
#   'firstPeriod': '1911',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['fødselstype', 'tid']},
#  {'id': 'FOD11',
#   'text': 'Gennemsnitsalder for fødende kvinder og nybagte fædre',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['alder', 'tid']},
#  {'id': 'FOD111',
#   'text': 'Gennemsnitsalder for fødende kvinder og nybagte fædre',
#   'unit': 'Gns.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'alder', 'tid']},
#  {'id': 'FORAELD',
#   'text': 'Antal forældre 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'antal børn', 'tid']},
#  {'id': 'BARNLOS',
#   'text': 'Barnløse pr. 1.000',
#   'unit': 'Pr. 1.000 indb.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['køn', 'alder', 'tid']},
#  {'id': 'FERT1',
#   'text': 'Samlet fertilitet (15-49 år)',
#   'unit': 'Pr. 1.000 kvinder',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['herkomst', 'tid']},
#  {'id': 'FOD33',
#   'text': 'Fertilitetskvotienter',
#   'unit': 'Pr. 1.000 kvinder',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1973',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['alder', 'tid']},
#  {'id': 'FOD407',
#   'text': 'Fertilitetskvotienter',
#   'unit': 'Pr. 1.000 kvinder',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'alder', 'tid']},
#  {'id': 'KOHORT01',
#   'text': 'Kumulerede fertilitetskvotienter for kvinders fødselsårgange',
#   'unit': 'Pr. 1.000 kvinder',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2023',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['fødselsår', 'alder', 'tid']},
#  {'id': 'DOD',
#   'text': 'Døde',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1974',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['alder', 'køn', 'tid']},
#  {'id': 'FOD207',
#   'text': 'Døde',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'alder', 'køn', 'tid']},
#  {'id': 'DODDAG',
#   'text': 'Døde',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['dødsdag', 'dødsmåned', 'tid']},
#  {'id': 'DODA1',
#   'text': 'Døde',
#   'unit': 'Antal',
#   'updated': '2024-03-13T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['dødsårsag', 'alder', 'køn', 'tid']},
#  {'id': 'DODB1',
#   'text': 'Døde',
#   'unit': 'Antal',
#   'updated': '2024-03-13T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['dødsårsag', 'køn', 'tid']},
#  {'id': 'DOD2',
#   'text': 'Døde under 5 år',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'tid']},
#  {'id': 'LIGEHI5A',
#   'text': 'Ligestillingsindikator for døde',
#   'unit': '-',
#   'updated': '2024-03-13T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['indikator', 'dødsårsag', 'alder', 'tid']},
#  {'id': 'HISB7',
#   'text': 'Middellevetid for 0-årige',
#   'unit': 'År',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1840:1849',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['køn', 'tid']},
#  {'id': 'HISBR',
#   'text': 'Middellevetid for 0-årige',
#   'unit': 'År',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2000:2001',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['område', 'køn', 'tid']},
#  {'id': 'LABY21',
#   'text': 'Middellevetid for 0-årige',
#   'unit': 'År',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006:2007',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['kommunegruppe', 'køn', 'tid']},
#  {'id': 'HISB77',
#   'text': 'Middellevetid for 0-årige',
#   'unit': 'År',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2000:2001',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['område', 'køn', 'tid']},
#  {'id': 'HISBK',
#   'text': 'Middellevetid for 0-årige',
#   'unit': 'År',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2000:2004',
#   'latestPeriod': '2020:2024',
#   'active': True,
#   'variables': ['område', 'køn', 'tid']},
#  {'id': 'HISB8',
#   'text': 'Dødelighedstavle (2-års tavler)',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1981:1982',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['alder', 'køn', 'dødelighedstavle', 'tid']},
#  {'id': 'HISB9',
#   'text': 'Dødelighedstavle (5-års tavler)',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1901:1905',
#   'latestPeriod': '2020:2024',
#   'active': True,
#   'variables': ['alder', 'køn', 'dødelighedstavle', 'tid']},
#  {'id': 'LIGEHI1',
#   'text': 'Ligestillingsindikator for middellevetid for 0-årige',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1901:1905',
#   'latestPeriod': '2023:2024',
#   'active': True,
#   'variables': ['indikator', 'tid']},
#  {'id': 'LIGEHI2',
#   'text': 'Ligestillingsindikator for middelrestlevetid for 50-årige',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1996:2000',
#   'latestPeriod': '2020:2024',
#   'active': True,
#   'variables': ['indikator', 'familietype', 'tid']},
#  {'id': 'LIGEHI4',
#   'text': 'Ligestillingsindikator for middelrestlevetid for 30-årige',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2012:2016',
#   'latestPeriod': '2020:2024',
#   'active': True,
#   'variables': ['indikator', 'højest fuldførte uddannelse', 'tid']},
#  {'id': 'FAM55N',
#   'text': 'Husstande 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'husstandstype',
#    'husstandsstørrelse',
#    'antal børn i husstand',
#    'tid']},
#  {'id': 'FAM122N',
#   'text': 'Voksne 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'husstandstype',
#    'antal personer i husstand ',
#    'antal børn i husstand',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'BY4',
#   'text': 'Husstande 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-05-14T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['byområder og landdistrikter',
#    'husstandstype',
#    'antal børn',
#    'tid']},
#  {'id': 'LABY50',
#   'text': 'Husstandes afstand til nærmeste dagligvarebutik',
#   'unit': 'Antal',
#   'updated': '2024-03-21T08:00:00',
#   'firstPeriod': '2009',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['kommunegruppe', 'afstand', 'tid']},
#  {'id': 'LABY50A',
#   'text': 'Husstandes afstand til nærmeste dagligvarebutik (andel i  pct.)',
#   'unit': 'Andel i pct.',
#   'updated': '2024-07-11T08:00:00',
#   'firstPeriod': '2009',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['kommunegruppe', 'afstand', 'tid']},
#  {'id': 'FAM44N',
#   'text': 'Familier 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'familietype',
#    'familiestørrelse',
#    'antal børn',
#    'tid']},
#  {'id': 'FAM44BA',
#   'text': 'Børnefamilier 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'enhed',
#    'familietype',
#    'børn fra alder',
#    'børn til alder',
#    'tid']},
#  {'id': 'LABY04',
#   'text': 'Familier m/u børn i procent af alle familier i samme kommune eller kommunegruppe',
#   'unit': 'Pct.',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område', 'familietype', 'tid']},
#  {'id': 'FAM100N',
#   'text': 'Voksne 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'familietype',
#    'antal personer i familien',
#    'antal børn i familien',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'FAM111N',
#   'text': 'Børn 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'familietype',
#    'antal personer i familien',
#    'antal børn i familien',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'FAM133N',
#   'text': 'Børn 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'husstandstype',
#    'antal personer i husstand ',
#    'antal børn i husstand',
#    'køn',
#    'alder',
#    'tid']},
#  {'id': 'BRN13',
#   'text': 'Børn',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'voksne i bopælsfamilien ',
#    'bopælsfamilietype',
#    'voksne i samværsfamilien  ',
#    'samværsfamilietype',
#    'alder',
#    'tid']},
#  {'id': 'BRN15',
#   'text': 'Børn fordelt på søskende de bor sammen med - antal og kombination',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'alder',
#    'familietype',
#    'antal søskende',
#    'kombination af søskende',
#    'tid']},
#  {'id': 'BRN16',
#   'text': 'Børn fordelt på alle søskende - antal og kombination',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'alder',
#    'familietype',
#    'antal søskende',
#    'kombination af søskende',
#    'tid']},
#  {'id': 'BRN9',
#   'text': 'Børn',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'alder',
#    'familietype',
#    'mor status',
#    'far status',
#    'tid']},
#  {'id': 'BRN11',
#   'text': 'Børn med familieskift',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'familieskift',
#    'familietype sidste år',
#    'familietype i år',
#    'alder',
#    'tid']},
#  {'id': 'BRN12',
#   'text': 'Børns (0-17-årige) familier',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['antal børn', 'børnefamilietype', 'familietype', 'tid']},
#  {'id': 'BRN10',
#   'text': 'Børn og unge (alle 0-29-årige) 1. januar, der har mistet forældre ved dødsfald',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2001',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'alder',
#    'mor status',
#    'far status',
#    'status på begge forældre',
#    'tid']},
#  {'id': 'LIGEFB7',
#   'text': 'Børn',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['alder', 'familietype', 'mor status', 'far status', 'tid']},
#  {'id': 'LIGEFI7',
#   'text': 'Ligestillingsindikator for børn, der har adresse kun hos mor eller far',
#   'unit': '-',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['indikator', 'alder', 'tid']},
#  {'id': 'PAAROE01',
#   'text': 'Gennemsnitsafstand (km) til 0-24-åriges bedsteforældre 1. januar',
#   'unit': 'Km',
#   'updated': '2025-03-04T08:00:00',
#   'firstPeriod': '2024',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['relationstype',
#    'hovedpersonens bopæl',
#    'hovedpersonens alder',
#    'tid']},
#  {'id': 'PAAROE02',
#   'text': 'Befolkningen (0-24-årige) 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-03-04T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['hovedpersonens alder', 'antal relationer', 'tid']},
#  {'id': 'PAAROE03',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-06-03T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['relation', 'hovedpersonens bopæl', 'tid']},
#  {'id': 'PAAROE04',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-06-03T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['relation', 'hovedpersonens alder', 'tid']},
#  {'id': 'PAAROE05',
#   'text': 'Befolkningen 1. januar',
#   'unit': 'Antal',
#   'updated': '2025-06-03T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['relation', 'hovedpersonens alder', 'tid']},
#  {'id': 'PAAROE30',
#   'text': 'Befolkningens kontakt til praktiserende læge (0-17 år)',
#   'unit': '-',
#   'updated': '2025-05-28T08:00:00',
#   'firstPeriod': '2021',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['relation', 'nøgletal', 'alder', 'køn', 'tid']},
#  {'id': 'PAAROE31',
#   'text': 'Befolkningens kontakt til praktiserende læge (18 år eller derover)',
#   'unit': '-',
#   'updated': '2025-05-28T08:00:00',
#   'firstPeriod': '2021',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['relation', 'nøgletal', 'alder', 'køn', 'tid']},
#  {'id': 'PAAROE35',
#   'text': 'Køb af receptpligtig medicin',
#   'unit': 'Antal',
#   'updated': '2026-01-06T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['relation', 'nøgletal', 'medicintype', 'alder', 'køn', 'tid']},
#  {'id': 'PAAROE40',
#   'text': 'Sygehusbenyttelse i befolkningen',
#   'unit': '-',
#   'updated': '2025-10-31T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['nøgletal',
#    'relation',
#    'sygehusvæsen',
#    'alder',
#    'køn',
#    'tid']},
#  {'id': 'PAAROE41',
#   'text': 'Sygehusbenyttelse i befolkningen',
#   'unit': '-',
#   'updated': '2025-10-31T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['nøgletal', 'relation', 'sygehustype', 'alder', 'køn', 'tid']},
#  {'id': 'PAAROE50',
#   'text': 'Personer visiteret til hjemmehjælp (andel af 65-84-årige)',
#   'unit': 'Pct.',
#   'updated': '2025-09-05T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['indikator', 'område', 'alder', 'relation', 'tid']},
#  {'id': 'PAAROE51',
#   'text': 'Visiteret hjemmehjælp, tid pr. person',
#   'unit': 'Gns. antal timer pr. uge',
#   'updated': '2025-09-05T08:00:00',
#   'firstPeriod': '2019',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['indikator', 'område', 'alder', 'relation', 'tid']},
#  {'id': 'VIE7',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '1989',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['type', 'tid']},
#  {'id': 'VIE9',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['vielsesmyndighed', 'vielsesmåned', 'tid']},
#  {'id': 'VIEDAG',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['vielsesdag', 'vielsesmåned', 'tid']},
#  {'id': 'VIE225',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons bopæl',
#    'Kvindens eller yngste persons bopæl',
#    'mandens eller ældste persons alder',
#    'kvindens eller yngste persons alder',
#    'mandens eller ældste persons tidligere civilstand',
#    'kvindens eller yngste persons tidligere civilstand',
#    'tid']},
#  {'id': 'VIE325',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons bopæl',
#    'Kvindens eller yngste persons bopæl',
#    'vielsesmåned',
#    'vielsesmyndighed',
#    'tid']},
#  {'id': 'VIE825',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons alder',
#    'kvindens eller yngste persons alder',
#    'vielsesmyndighed',
#    'tid']},
#  {'id': 'VIE1',
#   'text': 'Gennemsnitsalder for viede mænd og kvinder',
#   'unit': '-',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '1901',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['alder', 'tid']},
#  {'id': 'VIE7KVT',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2020M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['type', 'tid']},
#  {'id': 'VIE825K',
#   'text': 'Vielser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons alder',
#    'kvindens eller yngste persons alder',
#    'vielsesmyndighed',
#    'vielsesmåned',
#    'tid']},
#  {'id': 'SKI6',
#   'text': 'Skilsmisser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '1999',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['type', 'tid']},
#  {'id': 'SKI125',
#   'text': 'Skilsmisser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons bopæl',
#    'Kvindens eller yngste persons bopæl',
#    'mandens eller ældste persons alder',
#    'kvindens eller yngste persons alder',
#    'ægteskabets varighed',
#    'tid']},
#  {'id': 'SKI225',
#   'text': 'Skilsmisser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons bopæl',
#    'Kvindens eller yngste persons bopæl',
#    'skilsmissemåned',
#    'tid']},
#  {'id': 'SKI55',
#   'text': 'Skilsmisseprocent',
#   'unit': 'Pct.',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '1986',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'tid']},
#  {'id': 'OPL2025',
#   'text': 'Ægteskaber',
#   'unit': '-',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2025',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['vielsesår',
#    'ægteskabets varighed',
#    'ægteskabsopløsning',
#    'tid']},
#  {'id': 'SKI6KVT',
#   'text': 'Skilsmisser',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2020M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['type', 'tid']},
#  {'id': 'SKI125K',
#   'text': 'Skilsmisser',
#   'unit': 'Antal',
#   'updated': '2025-02-12T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['mandens eller ældste persons alder',
#    'kvindens eller yngste persons alder',
#    'ægteskabets varighed',
#    'skilsmissemåned',
#    'tid']},
#  {'id': 'BOERN8',
#   'text': 'Normeringer i kommunale og selvejende daginstitutioner, institutionslignende puljeordninger og dagpleje',
#   'unit': 'Antal',
#   'updated': '2026-02-09T08:00:00',
#   'firstPeriod': '2023',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['kommune', 'pasningstilbud', 'tid']},
#  {'id': 'BOERN2',
#   'text': 'Fuldtidsomregnet indskrevne børn i kommunale og selvejende daginstitutioner, puljeordninger og dagpleje',
#   'unit': 'Antal',
#   'updated': '2026-02-09T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'pasningstilbud', 'tid']},
#  {'id': 'BOERN1',
#   'text': 'Fuldtidsomregnet pædagogisk personale i kommunale og selvejende daginstitutioner, institutionslignende puljeordninger og dagpleje',
#   'unit': 'Antal',
#   'updated': '2026-02-09T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'stillingskategori', 'uddannelse', 'tid']},
#  {'id': 'PBOERN2',
#   'text': 'Fuldtidsomregnet indskrevne børn i private dagtilbudsinstitutioner',
#   'unit': 'Antal',
#   'updated': '2025-11-28T08:00:00',
#   'firstPeriod': '2021',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'pasningstilbud', 'tid']},
#  {'id': 'PBOERN1',
#   'text': 'Fuldtidsomregnet pædagogisk personale i private dagtilbudsinstitutioner',
#   'unit': 'Antal',
#   'updated': '2025-11-28T08:00:00',
#   'firstPeriod': '2021',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'stillingskategori', 'uddannelse', 'tid']},
#  {'id': 'BOERN5',
#   'text': 'Indskrevne børn i fritidsordninger',
#   'unit': 'Antal',
#   'updated': '2025-06-17T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'pasningstilbud', 'ejerform', 'alder', 'tid']},
#  {'id': 'BOERN61',
#   'text': 'Fuldtidsomregnet pædagogisk personale i kommunale skolefritidsordninger',
#   'unit': 'Antal',
#   'updated': '2025-06-17T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'stillingskategori', 'tid']},
#  {'id': 'DAGTIL4',
#   'text': 'Modtagere af tilskud vedr. privat pasning og pasning af egne børn',
#   'unit': 'Antal',
#   'updated': '2025-03-17T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'tilskudsart', 'berørte', 'tid']},
#  {'id': 'BOERN11',
#   'text': 'Fuldtidsomregnet pædagogisk personale ansat for statslige puljemidler',
#   'unit': 'Antal',
#   'updated': '2025-09-30T08:00:00',
#   'firstPeriod': '2023',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['kommune', 'stillingskategori', 'tid']},
#  {'id': 'BOERN10',
#   'text': 'Fuldtidsomregnet børn oprykket til børnehave, før den 1. i måneden, efter de er fyldt tre år',
#   'unit': 'Antal',
#   'updated': '2026-02-09T08:00:00',
#   'firstPeriod': '2023',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['kommune', 'tid']},
#  {'id': 'BOERN4',
#   'text': 'Institutioner og enheder',
#   'unit': 'Antal',
#   'updated': '2025-09-30T08:00:00',
#   'firstPeriod': '2017',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'pasningstilbud', 'ejerform', 'tid']},
#  {'id': 'RES88',
#   'text': 'Årstakster i børnepasning',
#   'unit': 'Kr.',
#   'updated': '2025-04-08T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område', 'foranstaltningsart', 'tid']},
#  {'id': 'FLY',
#   'text': 'Samtlige flytninger',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'tid']},
#  {'id': 'FLY33',
#   'text': 'Flytninger inden for kommuner',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'alder', 'køn', 'tid']},
#  {'id': 'FLY55',
#   'text': 'Flytninger mellem regioner',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn',
#    'alder',
#    'tilflytningsregion',
#    'fraflytningsregion',
#    'tid']},
#  {'id': 'FLY66',
#   'text': 'Flytninger mellem kommuner',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2006',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['tilflytningskommune',
#    'fraflytningskommune',
#    'alder',
#    'køn',
#    'tid']},
#  {'id': 'FLYDAG',
#   'text': 'Flytninger',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttedag', 'flyttemåned', 'tid']},
#  {'id': 'FLYUNG1',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype',
#    'fraflytningskommune',
#    'tilflytningssted',
#    'tid']},
#  {'id': 'FLYUNG2',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype',
#    'tilflytningskommune',
#    'tilflytningssted',
#    'tid']},
#  {'id': 'FLYUNG3',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype', 'fraflytningslandsdel', 'aldersgruppe', 'tid']},
#  {'id': 'FLYUNG4',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype', 'tilflytningslandsdel', 'aldersgruppe', 'tid']},
#  {'id': 'FLYUNG5',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype',
#    'fraflytningslandsdel',
#    'tilflytningslandsdel',
#    'tid']},
#  {'id': 'FLYUNG6',
#   'text': 'Flytninger blandt unge (15-29-årige)',
#   'unit': 'Antal',
#   'updated': '2025-06-26T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['flyttetype', 'alder', 'tilflytningssted', 'tid']},
#  {'id': 'VAN1KVT',
#   'text': 'Indvandringer (foreløbig opgørelse)',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2007K2',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'indvandringsland',
#    'statsborgerskab',
#    'tid']},
#  {'id': 'VAN1UGE',
#   'text': 'Indvandringer',
#   'unit': 'Antal',
#   'updated': '2026-01-12T08:00:00',
#   'firstPeriod': '2021U52',
#   'latestPeriod': '2026U01',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'indvandringsland',
#    'statsborgerskab',
#    'tid']},
#  {'id': 'VAN1AAR',
#   'text': 'Indvandringer',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'indvandringsland',
#    'statsborgerskab',
#    'tid']},
#  {'id': 'INDVAN',
#   'text': 'Indvandringer',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'statsborgerskab', 'indvandringsland', 'tid']},
#  {'id': 'VAN2KVT',
#   'text': 'Udvandringer (foreløbig opgørelse)',
#   'unit': 'Antal',
#   'updated': '2025-11-10T08:00:00',
#   'firstPeriod': '2007K2',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'udvandringsland',
#    'statsborgerskab',
#    'tid']},
#  {'id': 'VAN2AAR',
#   'text': 'Udvandringer',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område',
#    'køn',
#    'alder',
#    'udvandringsland',
#    'statsborgerskab',
#    'tid']},
#  {'id': 'UDVAN',
#   'text': 'Udvandringer',
#   'unit': 'Antal',
#   'updated': '2025-02-11T08:00:00',
#   'firstPeriod': '1980',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'statsborgerskab', 'udvandringsland', 'tid']},
#  {'id': 'BOL101',
#   'text': 'Boliger',
#   'unit': 'Antal',
#   'updated': '2025-03-18T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'beboertype',
#    'anvendelse',
#    'udlejningsforhold',
#    'ejerforhold',
#    'opførelsesår',
#    'tid']},
#  {'id': 'BOL102',
#   'text': 'Boliger',
#   'unit': 'Antal',
#   'updated': '2025-03-18T08:00:00',
#   'firstPeriod': '2010',
#   'latestPeriod': '2025',
#   'active': True,
#   'variables': ['område',
#    'beboertype',
#    'anvendelse',
#    'opførelsesår',
#    'opvarmning',
#    'toiletforhold',
# ...
#   'text': 'Offentligt forsørgede (aktiverede fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-12-18T08:00:00',
#   'firstPeriod': '2007K1',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['område', 'ydelsestype', 'køn', 'alder', 'tid']},
#  {'id': 'AUK04',
#   'text': 'Offentligt forsørgede (fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-12-18T08:00:00',
#   'firstPeriod': '2007K1',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['område', 'ydelsestype', 'oprindelsesland', 'køn', 'tid']},
#  {'id': 'AUK05',
#   'text': 'Offentligt forsørgede (støttet beskæftigelse, fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-12-18T08:00:00',
#   'firstPeriod': '2008K1',
#   'latestPeriod': '2025K3',
#   'active': True,
#   'variables': ['ydelsestype', 'sektor', 'køn', 'alder', 'tid']},
#  {'id': 'AUH01',
#   'text': 'Offentligt forsørgede (fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'ydelsestype', 'køn', 'alder', 'tid']},
#  {'id': 'AUH02',
#   'text': 'Offentligt forsørgede (fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['type', 'ydelsestype', 'alder', 'køn', 'tid']},
#  {'id': 'AUH03',
#   'text': 'Offentligt forsørgede (aktiverede fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'ydelsestype', 'køn', 'alder', 'tid']},
#  {'id': 'AUH04',
#   'text': 'Offentligt forsørgede (fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'ydelsestype', 'oprindelsesland', 'køn', 'tid']},
#  {'id': 'AUH05',
#   'text': 'Offentligt forsørgede (støttet beskæftigelse, fuldtidsmodtagere)',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2008',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['ydelsestype', 'sektor', 'køn', 'alder', 'tid']},
#  {'id': 'LIGEIB5',
#   'text': 'Offentligt forsørgede',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'ydelsestype', 'herkomst', 'tid']},
#  {'id': 'LIGEIB6',
#   'text': 'Offentligt forsørgede',
#   'unit': 'Antal',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['køn', 'alder', 'ydelsestype', 'familietype', 'tid']},
#  {'id': 'LIGEII5',
#   'text': 'Ligestillingsindikator for offentligt forsørgede',
#   'unit': '-',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['indikator', 'alder', 'ydelsestype', 'herkomst', 'tid']},
#  {'id': 'LIGEII6',
#   'text': 'Ligestillingsindikator for offentligt forsørgede',
#   'unit': 'Pr. 100.000 personer',
#   'updated': '2025-04-10T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['indikator', 'alder', 'ydelsestype', 'familietype', 'tid']},
#  {'id': 'KYS01',
#   'text': 'Kontanthjælp (sæsonkorrigeret)',
#   'unit': 'Antal',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2007M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['visitation', 'sæsonkorrigering', 'alder', 'køn', 'tid']},
#  {'id': 'KY21',
#   'text': 'Kontanthjælp (personer)',
#   'unit': 'Antal',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['visitation', 'alder', 'køn', 'tid']},
#  {'id': 'KY22',
#   'text': 'Kontanthjælp (personer)',
#   'unit': 'Antal',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['ydelsestype', 'alder', 'køn', 'tid']},
#  {'id': 'KY23',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'visitation', 'tid']},
#  {'id': 'KY24',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['område', 'enhed', 'visitation', 'tid']},
#  {'id': 'KY25',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype (detaljeret)', 'tid']},
#  {'id': 'KY26',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-12-10T08:00:00',
#   'firstPeriod': '2016M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['område', 'enhed', 'ydelsestype', 'tid']},
#  {'id': 'KY031',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'visitation', 'alder', 'køn', 'tid']},
#  {'id': 'KY032',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'alder', 'køn', 'tid']},
#  {'id': 'KY033',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'visitation', 'tid']},
#  {'id': 'KY034',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'område', 'tid']},
#  {'id': 'KY035',
#   'text': 'Kontanthjælp (helårsmodtagere)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'visitation', 'tid']},
#  {'id': 'KY036',
#   'text': 'Kontanthjælp detaljeret (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2016',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'tid']},
#  {'id': 'KY037',
#   'text': 'Kontanthjælp (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'familietype', 'tid']},
#  {'id': 'KY038',
#   'text': 'Kontanthjælp (helårsmodtagere)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område',
#    'ydelsestype',
#    'national oprindelse',
#    'herkomst',
#    'tid']},
#  {'id': 'KY050',
#   'text': 'Hjælp i særlige tilfælde (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['enhed', 'ydelsestype', 'alder', 'køn', 'tid']},
#  {'id': 'KY051',
#   'text': 'Hjælp i særlige tilfælde (personer og beløb)',
#   'unit': '-',
#   'updated': '2025-06-20T08:00:00',
#   'firstPeriod': '2007',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'enhed', 'ydelsestype', 'tid']},
#  {'id': 'SYGEDP01',
#   'text': 'Sygedagpenge',
#   'unit': '-',
#   'updated': '2025-05-27T08:00:00',
#   'firstPeriod': '2020',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['kommune', 'køn', 'alder', 'ydelsesmodtager', 'enhed', 'tid']},
#  {'id': 'BARSEL05',
#   'text': 'Samboende forældres orlov før fødslen samt i barnets første leveår',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'område',
#    'tid']},
#  {'id': 'BARSEL04',
#   'text': 'Forældres orlov før fødslen samt i barnets første leveår',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'område',
#    'tid']},
#  {'id': 'BARSEL06',
#   'text': 'Ikke samboende forældres orlov før fødslen samt i barnets første leveår',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['enhed',
#    'dagpengeret',
#    'eksistens',
#    'uddannelseskombination',
#    'område',
#    'tid']},
#  {'id': 'BARSEL11',
#   'text': 'Dage med barselsdagpenge (forældreårgange)',
#   'unit': '-',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'sektor',
#    'social status',
#    'branche',
#    'tid']},
#  {'id': 'BARSEL14',
#   'text': 'Dage med barselsdagpenge (forældreårgange)',
#   'unit': '-',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['enhed', 'berettigelse', 'branche', 'tid']},
#  {'id': 'BARSEL24',
#   'text': 'Orlov før fødslen og i barnet to første leveår for forældre med mere end 46 ugers',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2016',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'område',
#    'tid']},
#  {'id': 'BARSEL25',
#   'text': 'Orlov før fødslen og i barnet to første leveår for samboende forældre med mere end 46 ugers barselsorlov',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2016',
#   'latestPeriod': '2022',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'område',
#    'tid']},
#  {'id': 'BARLOV1',
#   'text': 'Orlov før fødslen samt i barnets første leveår afholdt af samboende forældre til et barn (født 2. august - 31. december)',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': 'AUG - DEC 2019',
#   'latestPeriod': 'AUG - DEC 2023',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'område',
#    'tid']},
#  {'id': 'BARLOV2',
#   'text': 'Samboende forældre på barselsorlov i barnets første leveår (børn født 2. august - 31. december)',
#   'unit': 'Antal',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': 'AUG - DEC 2019',
#   'latestPeriod': 'AUG - DEC 2023',
#   'active': True,
#   'variables': ['enhed',
#    'berettigelse',
#    'mors uddannelse',
#    'fars uddannelse',
#    'uger',
#    'tid']},
#  {'id': 'BARLOV3',
#   'text': 'Samboende forældre på barselsorlov i barnets første leveår (børn født 2. august - 31. december)',
#   'unit': 'Antal',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': 'AUG - DEC 2019',
#   'latestPeriod': 'AUG - DEC 2023',
#   'active': True,
#   'variables': ['enhed', 'berettigelse', 'område', 'uger', 'tid']},
#  {'id': 'LIGEFB1',
#   'text': 'Forældrepar',
#   'unit': 'Antal',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2016',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['barnets familieforhold',
#    'forældrenes dagpengeret',
#    'moderens højest fuldførte uddannelse',
#    'faderens højeste fuldførte uddannelse',
#    'område',
#    'tid']},
#  {'id': 'LIGEFI1',
#   'text': 'Ligestillingsindikator for barselsdagpengedage til forældrepar (gennemsnit)',
#   'unit': 'Dage',
#   'updated': '2026-02-05T08:00:00',
#   'firstPeriod': '2016',
#   'latestPeriod': '2023',
#   'active': True,
#   'variables': ['indikator',
#    'moderens højest fuldførte uddannelse',
#    'faderens højeste fuldførte uddannelse',
#    'forældrenes uddannelsesniveau',
#    'område',
#    'tid']},
#  {'id': 'PEN114',
#   'text': 'Folkepensionister',
#   'unit': '-',
#   'updated': '2026-01-08T08:00:00',
#   'firstPeriod': '2021M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'ydelsestype', 'modtagere', 'tid']},
#  {'id': 'PEN113',
#   'text': 'Førtidspensionister',
#   'unit': '-',
#   'updated': '2026-01-08T08:00:00',
#   'firstPeriod': '2021M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['område', 'køn', 'alder', 'ydelsestype', 'modtagere', 'tid']},
#  {'id': 'PEN124',
#   'text': 'Ydelse til folkepensionister med bopæl i Danmark',
#   'unit': '-',
#   'updated': '2026-01-08T08:00:00',
#   'firstPeriod': '2021M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['køn', 'alder', 'ydelsestype', 'familietype', 'enhed', 'tid']},
#  {'id': 'PEN123',
#   'text': 'Ydelse til førtidspensionister med bopæl i Danmark',
#   'unit': '-',
#   'updated': '2026-01-08T08:00:00',
#   'firstPeriod': '2021M01',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['køn', 'alder', 'ydelsestype', 'familietype', 'enhed', 'tid']},
#  {'id': 'PEN200',
#   'text': 'Befolkningen (67 år og derover)',
#   'unit': 'Antal',
#   'updated': '2026-01-08T08:00:00',
#   'firstPeriod': '2022M07',
#   'latestPeriod': '2025M09',
#   'active': True,
#   'variables': ['pensions- og beskæftigelsesstatus',
#    'alder',
#    'køn',
#    'ydelsestype',
#    'løntimer pr. uge',
#    'tid']},
#  {'id': 'BU43',
#   'text': 'Børn og unge der modtager støtte pr. 31. december (andel af 0-22-årige)',
#   'unit': 'Pct.',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2015',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'Foranstaltning', 'alder', 'tid']},
#  {'id': 'BU04A',
#   'text': 'Støtte til børn og unge pr. 31. december (nettoopgørelse)',
#   'unit': 'Antal',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2011',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['område', 'foranstaltning', 'alder', 'køn', 'tid']},
#  {'id': 'BU28',
#   'text': 'Samlede offentlige netto-driftsudgifter til udsatte børn og unge',
#   'unit': 'Mio. kr.',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2002',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['foranstaltning', 'tid']},
#  {'id': 'ANB5',
#   'text': 'Anbragte børn og unge pr. 30. juni og 31. december',
#   'unit': 'Antal',
#   'updated': '2026-01-28T08:00:00',
#   'firstPeriod': '2011H1',
#   'latestPeriod': '2025H1',
#   'active': True,
#   'variables': ['kommune', 'anbringelsessted', 'tid']},
#  {'id': 'ANB6',
#   'text': 'Anbragte børn og unge pr. 30. juni og 31. december',
#   'unit': 'Antal',
#   'updated': '2025-11-18T08:00:00',
#   'firstPeriod': '2011H1',
#   'latestPeriod': '2025H1',
#   'active': True,
#   'variables': ['kommune', 'foranstaltning', 'tid']},
#  {'id': 'ANB7',
#   'text': 'Anbragte børn og unge pr. 30. juni og 31. december',
#   'unit': 'Antal',
#   'updated': '2025-11-18T08:00:00',
#   'firstPeriod': '2011H1',
#   'latestPeriod': '2025H1',
#   'active': True,
#   'variables': ['kommune', 'alder', 'tid']},
#  {'id': 'ANBAAR2',
#   'text': 'Anbragte børn og unge pr. 31. december',
#   'unit': 'Antal',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2011',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['foranstaltning', 'alder', 'køn', 'tid']},
#  {'id': 'ANBAAR15',
#   'text': 'Anbragte børn og unge pr. 31. december',
#   'unit': 'Antal',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2011',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['anbringelsessted', 'alder', 'køn', 'tid']},
#  {'id': 'ANBAAR16',
#   'text': 'Anbragte børn og unge pr. 31. december',
#   'unit': 'Antal',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2011',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['landsdel',
#    'anbringelsessted',
#    'foranstaltning',
#    'alder',
#    'køn',
#    'tid']},
#  {'id': 'ANBAAR8',
#   'text': 'Iværksatte anbringelser af børn og unge',
#   'unit': 'Antal',
#   'updated': '2025-05-23T08:00:00',
#   'firstPeriod': '2011',
#   'latestPeriod': '2024',
#   'active': True,
#   'variables': ['landsdel', 'foranstaltning', 'alder', 'køn', 'tid']},
#  ...]

# %% [markdown]
# ### Test postDanStat()

# %%
# target (see targets above)
target = 'data'

# %%
# get table names from the website or from the previous response

# %%
# for data from table 'folk1c' - - use variables to filter the response
"""
targetid = 'folk1c'
variables = [{ "code": "ieland", "values": ["*"]}]
"""
# tripple quots make a multi-line comment in Pythion
# Out:
# '\ntargetid = \'folk1c\'\nvariables = [{ "code": "ieland", "values": ["*"]}]\n'

# %%
# for data from table LABY19 - use variables to filter the response
targetid = 'LABY19'
variables = [
    {"code":"ALDER", "values": ["*"]},
    {"code":"KOMGRP",  "values": ["*"]},
    {"code":"HØJEST FULDFØRTE UDDANNELSE", "values": "H30"},
    {"code":"ÅR", "values": "2024"}
]

# %%
# 'da' or 'en', Danish default
language = 'en'

# %%
outformat = 'csv'

# %%
response = postDanStat(baseurl, target, targetid, variables, outformat, language)

# %%
response.content
# Out:
# b'\xef\xbb\xbfALDER;KOMGRP;TID;INDHOLD\r\nAlder i alt;Hele landet;2024;4139094\r\nAlder i alt;Hovedstadskommuner;2024;1216678\r\nAlder i alt;Storbykommuner;2024;590351\r\nAlder i alt;Provinsbykommuner;2024;931291\r\nAlder i alt;Oplandskommuner;2024;637015\r\nAlder i alt;Landkommuner;2024;763759\r\nAlder i alt;K\xc3\xb8benhavn;2024;523292\r\nAlder i alt;Frederiksberg;2024;77388\r\nAlder i alt;Drag\xc3\xb8r;2024;8887\r\nAlder i alt;T\xc3\xa5rnby;2024;29920\r\nAlder i alt;Albertslund;2024;19150\r\nAlder i alt;Ballerup;2024;35688\r\nAlder i alt;Br\xc3\xb8ndby;2024;28222\r\nAlder i alt;Gentofte;2024;49964\r\nAlder i alt;Gladsaxe;2024;49452\r\nAlder i alt;Glostrup;2024;17139\r\nAlder i alt;Herlev;2024;20828\r\nAlder i alt;Hvidovre;2024;36932\r\nAlder i alt;H\xc3\xb8je-Taastrup;2024;41684\r\nAlder i alt;Ish\xc3\xb8j;2024;16992\r\nAlder i alt;Lyngby-Taarb\xc3\xa6k;2024;40686\r\nAlder i alt;R\xc3\xb8dovre;2024;31086\r\nAlder i alt;Vallensb\xc3\xa6k;2024;12083\r\nAlder i alt;Aller\xc3\xb8d;2024;16705\r\nAlder i alt;Egedal;2024;30361\r\nAlder i alt;Fredensborg;2024;27060\r\nAlder i alt;Frederikssund;2024;31249\r\nAlder i alt;Fures\xc3\xb8;2024;27043\r\nAlder i alt;Gribskov;2024;27164\r\nAlder i alt;Halsn\xc3\xa6s;2024;20707\r\nAlder i alt;Helsing\xc3\xb8r;2024;42008\r\nAlder i alt;Hiller\xc3\xb8d;2024;37646\r\nAlder i alt;H\xc3\xb8rsholm;2024;15372\r\nAlder i alt;Rudersdal;2024;36583\r\nAlder i alt;Bornholm;2024;24765\r\nAlder i alt;Christians\xc3\xb8;2024;65\r\nAlder i alt;Greve;2024;35120\r\nAlder i alt;K\xc3\xb8ge;2024;43114\r\nAlder i alt;Lejre;2024;19382\r\nAlder i alt;Roskilde;2024;62736\r\nAlder i alt;Solr\xc3\xb8d;2024;16101\r\nAlder i alt;Faxe;2024;25751\r\nAlder i alt;Guldborgsund;2024;38917\r\nAlder i alt;Holb\xc3\xa6k;2024;50280\r\nAlder i alt;Kalundborg;2024;32516\r\nAlder i alt;Lolland;2024;25317\r\nAlder i alt;N\xc3\xa6stved;2024;57826\r\nAlder i alt;Odsherred;2024;20409\r\nAlder i alt;Ringsted;2024;25497\r\nAlder i alt;Slagelse;2024;55045\r\nAlder i alt;Sor\xc3\xb8;2024;20598\r\nAlder i alt;Stevns;2024;15476\r\nAlder i alt;Vordingborg;2024;29747\r\nAlder i alt;Assens;2024;26822\r\nAlder i alt;Faaborg-Midtfyn;2024;34220\r\nAlder i alt;Kerteminde;2024;15507\r\nAlder i alt;Langeland;2024;7490\r\nAlder i alt;Middelfart;2024;26696\r\nAlder i alt;Nordfyns;2024;19721\r\nAlder i alt;Nyborg;2024;21408\r\nAlder i alt;Odense;2024;151903\r\nAlder i alt;Svendborg;2024;39341\r\nAlder i alt;\xc3\x86r\xc3\xb8;2024;3601\r\nAlder i alt;Billund;2024;18205\r\nAlder i alt;Esbjerg;2024;78072\r\nAlder i alt;Fan\xc3\xb8;2024;1906\r\nAlder i alt;Fredericia;2024;35900\r\nAlder i alt;Haderslev;2024;37123\r\nAlder i alt;Kolding;2024;65835\r\nAlder i alt;S\xc3\xb8nderborg;2024;49064\r\nAlder i alt;T\xc3\xb8nder;2024;23867\r\nAlder i alt;Varde;2024;32615\r\nAlder i alt;Vejen;2024;28698\r\nAlder i alt;Vejle;2024;83360\r\nAlder i alt;Aabenraa;2024;38645\r\nAlder i alt;Favrskov;2024;32668\r\nAlder i alt;Hedensted;2024;32491\r\nAlder i alt;Horsens;2024;67043\r\nAlder i alt;Norddjurs;2024;24432\r\nAlder i alt;Odder;2024;15543\r\nAlder i alt;Randers;2024;68394\r\nAlder i alt;Sams\xc3\xb8;2024;2247\r\nAlder i alt;Silkeborg;2024;68027\r\nAlder i alt;Skanderborg;2024;42544\r\nAlder i alt;Syddjurs;2024;28370\r\nAlder i alt;Aarhus;2024;277565\r\nAlder i alt;Herning;2024;60745\r\nAlder i alt;Holstebro;2024;39531\r\nAlder i alt;Ikast-Brande;2024;28966\r\nAlder i alt;Lemvig;2024;12322\r\nAlder i alt;Ringk\xc3\xb8bing-Skjern;2024;36910\r\nAlder i alt;Skive;2024;29448\r\nAlder i alt;Struer;2024;13167\r\nAlder i alt;Viborg;2024;66009\r\nAlder i alt;Br\xc3\xb8nderslev;2024;24069\r\nAlder i alt;Frederikshavn;2024;37726\r\nAlder i alt;Hj\xc3\xb8rring;2024;42024\r\nAlder i alt;Jammerbugt;2024;24721\r\nAlder i alt;L\xc3\xa6s\xc3\xb8;2024;991\r\nAlder i alt;Mariagerfjord;2024;27756\r\nAlder i alt;Mors\xc3\xb8;2024;12705\r\nAlder i alt;Rebild;2024;20197\r\nAlder i alt;Thisted;2024;28030\r\nAlder i alt;Vesthimmerlands;2024;23618\r\nAlder i alt;Aalborg;2024;160883\r\n15-19 \xc ...

# %% [markdown]
# ### From Response to DataFrame

# %%
# read it from the response format (outformat)
df = pd.read_csv(StringIO(response.text), sep=';')

# from json, if exists
# df = pd.read_json(StringIO(response.json()), orient="table")

# %%
df
# Out:
#             ALDER              KOMGRP   TID  INDHOLD
# 0     Alder i alt         Hele landet  2024  4139094
# 1     Alder i alt  Hovedstadskommuner  2024  1216678
# 2     Alder i alt      Storbykommuner  2024   590351
# 3     Alder i alt   Provinsbykommuner  2024   931291
# 4     Alder i alt     Oplandskommuner  2024   637015
# ...           ...                 ...   ...      ...
# 1255     65-69 år               Morsø  2024     1464
# 1256     65-69 år              Rebild  2024     1753
# 1257     65-69 år             Thisted  2024     3073
# 1258     65-69 år     Vesthimmerlands  2024     2466
# 1259     65-69 år             Aalborg  2024    11016
#
# [1260 rows x 4 columns]

# %%
# strore it in csv file
df.to_csv('../../data/danstat.csv')

# %%
# store to json, choices of orient (see the docs)
df.to_json('../../data/danstat.json', orient='records')

# %% [markdown]
# #### I/O Functions to Operate with JSON File

# %%
# write JSON file
def write_json(filename, list):               
    with open(filename, 'w') as f:
        json.dump(list, f)
    return

# %%
# read JSON file
def read_json(filename) -> pd.DataFrame:
    df = pd.read_json(filename)
    return df
